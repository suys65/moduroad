# %%
import networkx as nx
import pickle

file_path = 'C:/my_code/moduroad/moduroad_app/cashe_data/api_graph.pickle'

# Load the stored graph object
with open(file_path, 'rb') as file:
    api_graph = pickle.load(file)

# Assuming that api_graph is a NetworkX graph, let's iterate over all edges.
# We aim to change the 'weight' attribute to 'length' for each edge.
for u, v, data in api_graph.edges(data=True):
    # Store the 'weight' value
    weight = data['weight']
    # Assign the 'weight' value to a new attribute called 'length'
    data['length'] = weight
    # Now remove the 'weight' attribute
    del data['weight']

# %%
import pickle
import networkx as nx
file_path = 'C:/my_code/moduroad/moduroad_app/cashe_data/api_graph.pickle'

# Load the stored graph object
with open(file_path, 'rb') as file:
    api_graph = pickle.load(file)

for u, v, data in api_graph.edges(data=True):
    # Assign the 'weight' value to a new attribute called 'length'
    # Add 'slope' and 'stair' attributes, with default values of 0
    data['slope'] = 0
    data['stair_steep'] = 0
    data['sidewalk_curb'] = 0
    data['crosswalk_curb'] = 0
    data['bollard'] = 0
    data['access_zone'] = 0
    data['weight'] = 0
    # Now remove the 'weight' attribute
    

# api_graph가 이미 정의되어 있고 수정되었다고 가정

# 저장할 파일 경로 지정
file_path_to_save = 'C:/my_code/moduroad/moduroad_app/cashe_data/api_graph.pickle'

# api_graph 객체를 피클 파일로 저장
with open(file_path_to_save, 'wb') as file:
    pickle.dump(api_graph, file)

# %%
#엣지 데이터로 데이터프레임 으로 변환
import pandas as pd
import networkx as nx
import pickle
G=api_graph
# Graph 객체에서 엣지 정보를 불러와 DataFrame으로 변환
# 엣지 데이터는 (노드1, 노드2) 튜플의 리스트 형태이다
edges = list(G.edges(data=True))
# 데이터가 딕셔너리 형태의 속성(data=True)을 포함하는 경우
# 노드1, 노드2, 그리고 (키, 값) 쌍을 포함하는 딕셔너리를 포함한 튜플 형태인 경우 처리

# 엣지 정보를 DataFrame으로 변환 (노드1, 노드2, 속성 딕셔너리)
df_edges = pd.DataFrame(edges, columns=['Node1', 'Node2', 'Attributes'])

# 필요한 경우 속성 딕셔너리를 별도의 열로 확장할 수 있습니다
# 예를 들어, edge에 'weight' 속성이 있다면 다음과 같이 처리할 수 있습니다
# df_edges['Weight'] = df_edges['Attributes'].apply(lambda x: x.get('weight', None))

df_edges['Attributes'][0]
# Out:
# {'link_id': '28200000067',
#  'geometry': <LINESTRING (126.369 37.463, 126.369 37.463)>,
#  'length': 14.02555745870837}

# %%
import networkx as nx
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point, LineString
from shapely.strtree import STRtree
import pickle
import osmnx as ox
import folium
file_path = 'C:/my_code/moduroad/moduroad_app/cashe_data/api_graph.pickle'

with open(file_path, 'rb') as file:
    G = pickle.load(file)
G.graph['crs'] = 'epsg:4326'
# 장
obstacle_point = Point(	37.377069, 126.634596)


# 장애물 가까이에 있는 엣지 가중치 증가 함수 정의
def update_edge_weights(G, point, increment=1):
    # 가장 가까운 엣지 찾기
    nearest_edge_nodes = ox.distance.nearest_edges(G, X=point.y, Y=point.x)  # OSMnx는 (y, x) 형식으로 좌표를 사용합니다.
    print(nearest_edge_nodes)
    # nearest_edge_nodes는 (u, v, key) 형태의 튜플입니다.
    u, v, key = nearest_edge_nodes

    # 해당 엣지의 데이터 가져오기
    nearest_edge = G[u][v][key]
    print(nearest_edge)
    # 가장 가까운 엣지의 가중치 업데이트
    if nearest_edge:
        nearest_edge['bollard'] += increment
        print("change")
        print(nearest_edge)
        return (u, v, key), nearest_edge
    
m = folium.Map(location=[37.37463, 126.64481], zoom_start=14)    


modified_edge, edge_data = update_edge_weights(G, obstacle_point)
combined_line_string = edge_data['geometry']


# 합쳐진 LineString을 Folium 지도에 추가 (비어 있지 않은 경우에만 추가)
if combined_line_string:
    folium.GeoJson(combined_line_string, style_function=lambda x: {'color': 'blue', 'weight': 5}).add_to(m)
else:
    print("지도에 추가할 LineString이 없습니다.")
# 시작 지점에 마커 추가
folium.Marker(
    location=[obstacle_point.x,obstacle_point.y],
    icon=folium.Icon(color='red')
).add_to(m)

m
# Out:
# ('28000761546', '28000762852', 0)
# {'link_id': '28200362607', 'weight': 63.702618998460366, 'geometry': <LINESTRING (126.635 37.377, 126.635 37.377, 126.635 37.377, 126.635 37.377,...>}
# change
# {'link_id': '28200362607', 'weight': 68.70261899846037, 'geometry': <LINESTRING (126.635 37.377, 126.635 37.377, 126.635 37.377, 126.635 37.377,...>}
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f26d8808f233db09e0bdb9c0333ff28 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f26d8808f233db09e0bdb9c0333ff28&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f26d8808f233db09e0bdb9c0333ff28 = L.map(
#                 &quot;map_4f26d8808f233db09e0bdb9c0333ff28&quot;,
#                 {
#                     center: [37.37463, 126.64481],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5f85bcb553fe3e0ed1b5dff6bef57fe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c5f85bcb553fe3e0ed1b5dff6bef57fe.addTo(map_4f26d8808f233db09e0bdb9c0333ff28);
#
#
#         function geo_json_213b6d3c10c15648748a6f36efd50450_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;weight&quot;: 5};
#             }
#         }
#
#         function geo_json_213b6d3c10c15648748a6f36efd50450_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_213b6d3c10c15648748a6f36efd50450 = L.geoJson(null, {
#                 onEachFeature: geo_json_213b6d3c10c15648748a6f36efd50450_onEachFeature,
#
#                 style: geo_json_213b6d3c10c15648748a6f36efd50450_styler,
#         });
#
#         function geo_json_213b6d3c10c15648748a6f36efd50450_add (data) {
#             geo_json_213b6d3c10c15648748a6f36efd50450
#                 .addData(data);
#         }
#             geo_json_213b6d3c10c15648748a6f36efd50450_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[126.63478155071633, 37.37684797858778], [126.6346998519942, 37.37699117200948], [126.63458576275337, 37.37705811783098], [126.63459365594137, 37.377070838883604], [126.63476357480899, 37.37697486171167], [126.63486101540988, 37.37707054110343]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_213b6d3c10c15648748a6f36efd50450.addTo(map_4f26d8808f233db09e0bdb9c0333ff28);
#
#
#             var marker_5d41ae5d1e5d4eb818b8d47dd765c854 = L.marker(
#                 [37.377069, 126.634596],
#                 {}
#             ).addTo(map_4f26d8808f233db09e0bdb9c0333ff28);
#
#
#             var icon_f3a0a7d83487b208ca4abd5a444f2237 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5d41ae5d1e5d4eb818b8d47dd765c854.setIcon(icon_f3a0a7d83487b208ca4abd5a444f2237);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd# Load the DataFrame from the pickle file
pickle_file_path = 'C:/my_code/moduroad/data/obstacle/slope.pkl'  # Replace with your pickle file path
obstacle_df = pd.read_pickle(pickle_file_path)

# 모든 행의 데이터를 오른쪽으로 1칸씩 이동
obstacle_df = obstacle_df.shift(periods=1, axis='columns')

# 첫 번째 열 삭제 ('hg' 열이 이동 후 첫 번째 열임)
obstacle_df.drop(obstacle_df.columns[0], axis=1, inplace=True)

# 새로운 열 이름 지정 (예시에서 주어진 열 이름 사용)
new_columns = ['ctprvnnm', 'signgunm', 'signgucode', 'rdnmadr', 'lnmadr', 'latitude', 'longitude', 'institutionnm', 'phonenumeric', 'referencedate', 'instt_code', 'instt_nm', 'handicapcvntlyn', 'handicapcvntltype']
obstacle_df.columns = new_columns


obstacle_df
# Out:
#      ctprvnnm signgunm signgucode                               rdnmadr  \
# 0       인천광역시      남동구      28200
# 1       인천광역시      남동구      28200
# 2       인천광역시      남동구      28200
# 3       인천광역시     미추홀구      28177
# 4       인천광역시     미추홀구      28177
# ...       ...      ...        ...                                   ...
# 7751    인천광역시     미추홀구      28177      인천광역시 미추홀구 낙섬중로 20, (용현동, 한양아파트)
# 7752    인천광역시      남동구      28200      인천광역시 남동구 담방로 29, (만수동, 광명아파트상가)
# 7753    인천광역시      남동구      28200  인천광역시 남동구 장승남로 70-11, (만수동, 현대아파트상가)
# 7754    인천광역시      계양구      28245           인천광역시 계양구 선주로56번길 5, (선주지동)
# 7755    인천광역시      계양구      28245           인천광역시 계양구 선주로56번길 5, (선주지동)
#
#                       lnmadr   latitude   longitude institutionnm  \
# 0      인천광역시 남동구 남촌도림동 648-5  37.421526   126.72953        인천광역시청
# 1       인천광역시 남동구 논현2동 685-0  37.405426  126.723187        인천광역시청
# 2       인천광역시 남동구 논현2동 688-0  37.405726  126.723106        인천광역시청
# 3       인천광역시 미추홀구 관교동 520-0  37.445083  126.689948        인천광역시청
# 4       인천광역시 미추홀구 관교동 520-0  37.445562  126.690162        인천광역시청
# ...                      ...        ...         ...           ...
# 7751  인천광역시 미추홀구 용현5동 627-78  37.450717  126.638515        인천광역시청
# 7752   인천광역시 남동구 만수6동 1042-0  37.441782  126.736736        인천광역시청
# 7753   인천광역시 남동구 만수6동 1037-0  37.441915  126.740316        인천광역시청
# 7754    인천광역시 계양구 계양1동 108-4  37.574715  126.737592        인천광역시청
# 7755    인천광역시 계양구 계양1동 108-4  37.574869   126.73749        인천광역시청
#
#      phonenumeric referencedate instt_code instt_nm handicapcvntlyn  \
# 0                    2021-12-03                                   Y
# 1                    2021-12-03                                   Y
# 2                    2021-12-03                                   Y
# 3                    2021-12-03                                   Y
# 4                    2021-12-03                                   Y
# ...           ...           ...        ...      ...             ...
# 7751                 2021-12-03                                   Y
# 7752                 2021-12-03                                   Y
# 7753                 2021-12-03                                   Y
# 7754                 2021-12-03                                   Y
# 7755                 2021-12-03                                   Y
#
#      handicapcvntltype
# 0                  경사로
# 1                  경사로
# 2                  경사로
# 3                  경사로
# 4                  경사로
# ...                ...
# 7751               경사로
# 7752               경사로
# 7753               경사로
# 7754               경사로
# 7755               경사로
#
# [7756 rows x 14 columns]

# %%
obstacle_df['signgucode'] = pd.to_numeric(obstacle_df['signgucode'], errors='coerce')
obstacle_df['latitude'] = pd.to_numeric(obstacle_df['latitude'], errors='coerce')
obstacle_df['longitude'] = pd.to_numeric(obstacle_df['longitude'], errors='coerce')
print(obstacle_df.dtypes)
# Out:
# ctprvnnm              object
# signgunm              object
# signgucode             int64
# rdnmadr               object
# lnmadr                object
# latitude             float64
# longitude            float64
# institutionnm         object
# phonenumeric          object
# referencedate         object
# instt_code            object
# instt_nm              object
# handicapcvntlyn       object
# handicapcvntltype     object
# dtype: object

# %%
# obstacle_df DataFrame을 'C:/my_code/moduroad/data/obstacle/slope.pkl' 경로로 저장합니다.
obstacle_df.to_pickle('C:/my_code/moduroad/data/obstacle/slope.pkl')

# %%
file_path = 'C:/my_code/moduroad/moduroad_app/cashe_data/api_graph.pickle'

with open(file_path, 'rb') as file:
    G = pickle.load(file)

# %%
import pandas as pd
import osmnx as ox
from shapely.geometry import Point
import networkx as nx
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point, LineString
from shapely.strtree import STRtree
import pickle
import osmnx as ox
import folium
file_path = 'C:/my_code/moduroad/moduroad_app/cashe_data/api_graph.pickle'

with open(file_path, 'rb') as file:
    G = pickle.load(file)
# Load the DataFrame from the pickle file
pickle_file_path = 'C:/my_code/moduroad/data/obstacle/bollard.pkl'  # Replace with your pickle file path
obstacle_df = pd.read_pickle(pickle_file_path)

G.graph['crs'] = 'epsg:4326'

# 장애물 가까이에 있는 엣지 가중치 증가 함수 정의
def update_edge_weights(G, point, attribute_name='bollard', increment=1):
    # 가장 가까운 엣지 찾기
    
    nearest_edge_nodes = ox.distance.nearest_edges(G, X=point.x, Y=point.y)  # OSMnx는 (y, x) 형식으로 좌표를 사용합니다.
    
    # nearest_edge_nodes는 (u, v, key) 형태의 튜플입니다.
    u, v, key = nearest_edge_nodes
    
    # 해당 엣지의 데이터 가져오기
    nearest_edge = G[u][v][key]
    print(nearest_edge)
    # 가장 가까운 엣지의 가중치 업데이트
    # 시작 지점에 마커 추가
    
    if attribute_name in nearest_edge:
    # 속성 값이 0인지 확인합니다.
        if nearest_edge[attribute_name] == 0:
            # 속성 값이 0이라면, 새로운 포인트를 포함하는 리스트로 변경합니다.
            nearest_edge[attribute_name] = [point]
        elif isinstance(nearest_edge[attribute_name], list):
            # 속성 값이 리스트인 경우, 새로운 포인트를 리스트에 추가합니다.
            nearest_edge[attribute_name].append(point)
        else:
            # 속성 값이 0이 아니고 리스트도 아닌 다른 값인 경우, 그 값을 리스트에 넣고 새로운 포인트도 추가합니다.
            current_value = nearest_edge[attribute_name]
            nearest_edge[attribute_name] = [current_value, point]
            #print("change")
        print(nearest_edge)
    
        return (u, v, key), nearest_edge
    
i=0
# 모든 장애물에 대해 가중치 업데이트 함수 실행
for index, obstacle in obstacle_df.iterrows():
    latitude = obstacle['latitude']
    longitude = obstacle['longitude']
    print(i)
    # Point 객체 생성
    points= Point(longitude, latitude)
    # 가장 가까운 엣지의 가중치 업데이트 함수 적용
    updated_edge_info = update_edge_weights(G, points, increment=1)
    i+=1
# Out:
# 0
# {'link_id': '28300190107', 'geometry': <LINESTRING (126.667 37.596, 126.667 37.596)>, 'length': 5.241969447245253, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300190107', 'geometry': <LINESTRING (126.667 37.596, 126.667 37.596)>, 'length': 5.241969447245253, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.667 37.596)>], 'access_zone': 0, 'weight': 0}
# 1
# {'link_id': '28100010753', 'geometry': <LINESTRING (126.671 37.59, 126.671 37.59, 126.671 37.59, 126.671 37.59, 126...>, 'length': 79.46624196610406, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100010753', 'geometry': <LINESTRING (126.671 37.59, 126.671 37.59, 126.671 37.59, 126.671 37.59, 126...>, 'length': 79.46624196610406, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.671 37.59)>], 'access_zone': 0, 'weight': 0}
# 2
# {'link_id': '28300188245', 'geometry': <LINESTRING (126.67 37.592, 126.67 37.592)>, 'length': 1.9616329964898753, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300188245', 'geometry': <LINESTRING (126.67 37.592, 126.67 37.592)>, 'length': 1.9616329964898753, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.67 37.592)>], 'access_zone': 0, 'weight': 0}
# 3
# {'link_id': '28300190042', 'geometry': <LINESTRING (126.67 37.596, 126.67 37.596)>, 'length': 5.594401066599996, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300190042', 'geometry': <LINESTRING (126.67 37.596, 126.67 37.596)>, 'length': 5.594401066599996, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.67 37.596)>], 'access_zone': 0, 'weight': 0}
# 4
# {'link_id': '28100002603', 'geometry': <LINESTRING (126.665 37.599, 126.665 37.599)>, 'length': 13.62683810052672, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100002603', 'geometry': <LINESTRING (126.665 37.599, 126.665 37.599)>, 'length': 13.62683810052672, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.665 37.599)>], 'access_zone': 0, 'weight': 0}
# 5
# {'link_id': '28300191572', 'geometry': <LINESTRING (126.671 37.547, 126.671 37.547)>, 'length': 4.790826149506182, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300191572', 'geometry': <LINESTRING (126.671 37.547, 126.671 37.547)>, 'length': 4.790826149506182, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.671 37.547)>], 'access_zone': 0, 'weight': 0}
# 6
# {'link_id': '28300140317', 'geometry': <LINESTRING (126.661 37.385, 126.661 37.385)>, 'length': 5.467477536615949, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300140317', 'geometry': <LINESTRING (126.661 37.385, 126.661 37.385)>, 'length': 5.467477536615949, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.661 37.385)>], 'access_zone': 0, 'weight': 0}
# 7
# {'link_id': '28300320131', 'geometry': <LINESTRING (126.662 37.385, 126.662 37.385)>, 'length': 6.092724757465488, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300320131', 'geometry': <LINESTRING (126.662 37.385, 126.662 37.385)>, 'length': 6.092724757465488, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.662 37.385)>], 'access_zone': 0, 'weight': 0}
# 8
# {'link_id': '28200320129', 'geometry': <LINESTRING (126.662 37.385, 126.662 37.385)>, 'length': 12.239470314161904, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200320129', 'geometry': <LINESTRING (126.662 37.385, 126.662 37.385)>, 'length': 12.239470314161904, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.662 37.385)>], 'access_zone': 0, 'weight': 0}
# 9
# {'link_id': '28200258860', 'geometry': <LINESTRING (126.662 37.385, 126.662 37.385)>, 'length': 8.005317815696928, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200258860', 'geometry': <LINESTRING (126.662 37.385, 126.662 37.385)>, 'length': 8.005317815696928, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.662 37.385)>], 'access_zone': 0, 'weight': 0}
# 10
# {'link_id': '28100405066', 'geometry': <LINESTRING (126.66 37.384, 126.659 37.384)>, 'length': 59.80088651646591, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100405066', 'geometry': <LINESTRING (126.66 37.384, 126.659 37.384)>, 'length': 59.80088651646591, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.66 37.384)>], 'access_zone': 0, 'weight': 0}
# 11
# {'link_id': '28300140061', 'geometry': <LINESTRING (126.66 37.383, 126.66 37.383)>, 'length': 0.9124612096362706, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300140061', 'geometry': <LINESTRING (126.66 37.383, 126.66 37.383)>, 'length': 0.9124612096362706, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.66 37.383)>], 'access_zone': 0, 'weight': 0}
# 12
# {'link_id': '28300319774', 'geometry': <LINESTRING (126.658 37.383, 126.658 37.383)>, 'length': 1.8108523181416452, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300319774', 'geometry': <LINESTRING (126.658 37.383, 126.658 37.383)>, 'length': 1.8108523181416452, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.658 37.383)>], 'access_zone': 0, 'weight': 0}
# 13
# {'link_id': '28100319773', 'geometry': <LINESTRING (126.659 37.384, 126.659 37.384, 126.658 37.383, 126.658 37.383,...>, 'length': 145.79815180049124, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100319773', 'geometry': <LINESTRING (126.659 37.384, 126.659 37.384, 126.658 37.383, 126.658 37.383,...>, 'length': 145.79815180049124, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.658 37.383)>], 'access_zone': 0, 'weight': 0}
# 14
# {'link_id': '28100039285', 'geometry': <LINESTRING (126.66 37.382, 126.66 37.382)>, 'length': 3.079218770040096, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100039285', 'geometry': <LINESTRING (126.66 37.382, 126.66 37.382)>, 'length': 3.079218770040096, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.66 37.382)>], 'access_zone': 0, 'weight': 0}
# 15
# {'link_id': '28100039286', 'geometry': <LINESTRING (126.66 37.382, 126.66 37.382)>, 'length': 8.552398230268675, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100039286', 'geometry': <LINESTRING (126.66 37.382, 126.66 37.382)>, 'length': 8.552398230268675, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.66 37.382)>], 'access_zone': 0, 'weight': 0}
# 16
# {'link_id': '28300319622', 'geometry': <LINESTRING (126.658 37.381, 126.658 37.381)>, 'length': 5.277206554910664, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300319622', 'geometry': <LINESTRING (126.658 37.381, 126.658 37.381)>, 'length': 5.277206554910664, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.658 37.381)>], 'access_zone': 0, 'weight': 0}
# 17
# {'link_id': '28300319796', 'geometry': <LINESTRING (126.658 37.381, 126.658 37.381)>, 'length': 5.181541348457756, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300319796', 'geometry': <LINESTRING (126.658 37.381, 126.658 37.381)>, 'length': 5.181541348457756, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.658 37.381)>], 'access_zone': 0, 'weight': 0}
# 18
# {'link_id': '28300194165', 'geometry': <LINESTRING (126.661 37.38, 126.661 37.38)>, 'length': 7.682663562316168, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300194165', 'geometry': <LINESTRING (126.661 37.38, 126.661 37.38)>, 'length': 7.682663562316168, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.661 37.38)>], 'access_zone': 0, 'weight': 0}
# 19
# {'link_id': '28300140052', 'geometry': <LINESTRING (126.659 37.382, 126.659 37.382)>, 'length': 8.580967973007452, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300140052', 'geometry': <LINESTRING (126.659 37.382, 126.659 37.382)>, 'length': 8.580967973007452, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.659 37.382)>], 'access_zone': 0, 'weight': 0}
# 20
# {'link_id': '28300140052', 'geometry': <LINESTRING (126.659 37.382, 126.659 37.382)>, 'length': 8.580967973007452, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.659 37.382)>], 'access_zone': 0, 'weight': 0}
# {'link_id': '28300140052', 'geometry': <LINESTRING (126.659 37.382, 126.659 37.382)>, 'length': 8.580967973007452, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.659 37.382)>, <POINT (126.659 37.382)>], 'access_zone': 0, 'weight': 0}
# 21
# {'link_id': '28300194167', 'geometry': <LINESTRING (126.663 37.381, 126.663 37.381)>, 'length': 6.563206510405792, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300194167', 'geometry': <LINESTRING (126.663 37.381, 126.663 37.381)>, 'length': 6.563206510405792, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.663 37.381)>], 'access_zone': 0, 'weight': 0}
# 22
# {'link_id': '28300382884', 'geometry': <LINESTRING (126.668 37.381, 126.668 37.381)>, 'length': 40.07810362779186, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300382884', 'geometry': <LINESTRING (126.668 37.381, 126.668 37.381)>, 'length': 40.07810362779186, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.668 37.381)>], 'access_zone': 0, 'weight': 0}
# 23
# {'link_id': '28300382884', 'geometry': <LINESTRING (126.668 37.381, 126.668 37.381)>, 'length': 40.07810362779186, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.668 37.381)>], 'access_zone': 0, 'weight': 0}
# {'link_id': '28300382884', 'geometry': <LINESTRING (126.668 37.381, 126.668 37.381)>, 'length': 40.07810362779186, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.668 37.381)>, <POINT (126.668 37.381)>], 'access_zone': 0, 'weight': 0}
# 24
# {'link_id': '28100078995', 'geometry': <LINESTRING (126.663 37.379, 126.663 37.379)>, 'length': 59.88323708019733, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100078995', 'geometry': <LINESTRING (126.663 37.379, 126.663 37.379)>, 'length': 59.88323708019733, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.663 37.379)>], 'access_zone': 0, 'weight': 0}
# 25
# {'link_id': '28300137970', 'geometry': <LINESTRING (126.664 37.369, 126.664 37.369, 126.664 37.369, 126.665 37.369,...>, 'length': 194.75204831770665, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300137970', 'geometry': <LINESTRING (126.664 37.369, 126.664 37.369, 126.664 37.369, 126.665 37.369,...>, 'length': 194.75204831770665, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.665 37.37)>], 'access_zone': 0, 'weight': 0}
# 26
# {'link_id': '28200255032', 'geometry': <LINESTRING (126.66 37.374, 126.66 37.374)>, 'length': 21.830410826222753, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200255032', 'geometry': <LINESTRING (126.66 37.374, 126.66 37.374)>, 'length': 21.830410826222753, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.66 37.374)>], 'access_zone': 0, 'weight': 0}
# 27
# {'link_id': '28100381022', 'geometry': <LINESTRING (126.656 37.37, 126.656 37.37)>, 'length': 5.5953151852399055, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100381022', 'geometry': <LINESTRING (126.656 37.37, 126.656 37.37)>, 'length': 5.5953151852399055, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.656 37.37)>], 'access_zone': 0, 'weight': 0}
# 28
# {'link_id': '28300381028', 'geometry': <LINESTRING (126.656 37.37, 126.656 37.37)>, 'length': 7.009904911792849, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300381028', 'geometry': <LINESTRING (126.656 37.37, 126.656 37.37)>, 'length': 7.009904911792849, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.656 37.37)>], 'access_zone': 0, 'weight': 0}
# 29
# {'link_id': '28100381023', 'geometry': <LINESTRING (126.656 37.37, 126.656 37.37)>, 'length': 5.711392297757706, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100381023', 'geometry': <LINESTRING (126.656 37.37, 126.656 37.37)>, 'length': 5.711392297757706, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.656 37.37)>], 'access_zone': 0, 'weight': 0}
# 30
# {'link_id': '28100381018', 'geometry': <LINESTRING (126.656 37.37, 126.656 37.37, 126.656 37.37, 126.656 37.37, 126...>, 'length': 25.241259996723745, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100381018', 'geometry': <LINESTRING (126.656 37.37, 126.656 37.37, 126.656 37.37, 126.656 37.37, 126...>, 'length': 25.241259996723745, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.656 37.37)>], 'access_zone': 0, 'weight': 0}
# 31
# {'link_id': '28100380181', 'geometry': <LINESTRING (126.653 37.372, 126.653 37.372, 126.653 37.372, 126.653 37.372,...>, 'length': 35.178447211088525, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100380181', 'geometry': <LINESTRING (126.653 37.372, 126.653 37.372, 126.653 37.372, 126.653 37.372,...>, 'length': 35.178447211088525, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.653 37.372)>], 'access_zone': 0, 'weight': 0}
# 32
# {'link_id': '28300380193', 'geometry': <LINESTRING (126.653 37.372, 126.653 37.372)>, 'length': 12.419147606790972, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300380193', 'geometry': <LINESTRING (126.653 37.372, 126.653 37.372)>, 'length': 12.419147606790972, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.653 37.372)>], 'access_zone': 0, 'weight': 0}
# 33
# {'link_id': '28100380183', 'geometry': <LINESTRING (126.653 37.372, 126.653 37.372, 126.653 37.372, 126.653 37.372,...>, 'length': 9.41802039142862, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100380183', 'geometry': <LINESTRING (126.653 37.372, 126.653 37.372, 126.653 37.372, 126.653 37.372,...>, 'length': 9.41802039142862, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.653 37.372)>], 'access_zone': 0, 'weight': 0}
# 34
# {'link_id': '28100382803', 'geometry': <LINESTRING (126.67 37.381, 126.67 37.381, 126.67 37.381, 126.67 37.381, 126...>, 'length': 12.816276028117667, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100382803', 'geometry': <LINESTRING (126.67 37.381, 126.67 37.381, 126.67 37.381, 126.67 37.381, 126...>, 'length': 12.816276028117667, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.67 37.381)>], 'access_zone': 0, 'weight': 0}
# 35
# {'link_id': '28100382810', 'geometry': <LINESTRING (126.67 37.381, 126.67 37.381, 126.67 37.381, 126.67 37.381, 126...>, 'length': 15.019500470110128, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100382810', 'geometry': <LINESTRING (126.67 37.381, 126.67 37.381, 126.67 37.381, 126.67 37.381, 126...>, 'length': 15.019500470110128, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.67 37.381)>], 'access_zone': 0, 'weight': 0}
# 36
# {'link_id': '28200382994', 'geometry': <LINESTRING (126.67 37.381, 126.67 37.381)>, 'length': 27.692964818337153, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200382994', 'geometry': <LINESTRING (126.67 37.381, 126.67 37.381)>, 'length': 27.692964818337153, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.67 37.381)>], 'access_zone': 0, 'weight': 0}
# 37
# {'link_id': '28100382823', 'geometry': <LINESTRING (126.667 37.383, 126.667 37.383, 126.667 37.383)>, 'length': 25.327289286104453, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100382823', 'geometry': <LINESTRING (126.667 37.383, 126.667 37.383, 126.667 37.383)>, 'length': 25.327289286104453, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.667 37.383)>], 'access_zone': 0, 'weight': 0}
# 38
# {'link_id': '28100382829', 'geometry': <LINESTRING (126.667 37.383, 126.667 37.383, 126.667 37.383)>, 'length': 17.913370803326444, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100382829', 'geometry': <LINESTRING (126.667 37.383, 126.667 37.383, 126.667 37.383)>, 'length': 17.913370803326444, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.667 37.383)>], 'access_zone': 0, 'weight': 0}
# 39
# {'link_id': '28100382822', 'geometry': <LINESTRING (126.667 37.383, 126.667 37.383, 126.667 37.383)>, 'length': 16.34791519528325, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100382822', 'geometry': <LINESTRING (126.667 37.383, 126.667 37.383, 126.667 37.383)>, 'length': 16.34791519528325, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.667 37.383)>], 'access_zone': 0, 'weight': 0}
# 40
# {'link_id': '28100382823', 'geometry': <LINESTRING (126.667 37.383, 126.667 37.383, 126.667 37.383)>, 'length': 25.327289286104453, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.667 37.383)>], 'access_zone': 0, 'weight': 0}
# {'link_id': '28100382823', 'geometry': <LINESTRING (126.667 37.383, 126.667 37.383, 126.667 37.383)>, 'length': 25.327289286104453, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.667 37.383)>, <POINT (126.667 37.383)>], 'access_zone': 0, 'weight': 0}
# 41
# {'link_id': '28100382840', 'geometry': <LINESTRING (126.669 37.382, 126.669 37.381)>, 'length': 5.711156982592352, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100382840', 'geometry': <LINESTRING (126.669 37.382, 126.669 37.381)>, 'length': 5.711156982592352, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.669 37.381)>], 'access_zone': 0, 'weight': 0}
# 42
# {'link_id': '28100382811', 'geometry': <LINESTRING (126.669 37.381, 126.669 37.381)>, 'length': 12.219323541801167, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100382811', 'geometry': <LINESTRING (126.669 37.381, 126.669 37.381)>, 'length': 12.219323541801167, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.669 37.381)>], 'access_zone': 0, 'weight': 0}
# 43
# {'link_id': '28300382887', 'geometry': <LINESTRING (126.668 37.382, 126.668 37.382, 126.669 37.381)>, 'length': 40.0574381103804, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300382887', 'geometry': <LINESTRING (126.668 37.382, 126.668 37.382, 126.669 37.381)>, 'length': 40.0574381103804, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.668 37.382)>], 'access_zone': 0, 'weight': 0}
# 44
# {'link_id': '28100382858', 'geometry': <LINESTRING (126.668 37.382, 126.669 37.382, 126.669 37.382)>, 'length': 14.852673423353181, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100382858', 'geometry': <LINESTRING (126.668 37.382, 126.669 37.382, 126.669 37.382)>, 'length': 14.852673423353181, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.668 37.382)>], 'access_zone': 0, 'weight': 0}
# 45
# {'link_id': '28100381898', 'geometry': <LINESTRING (126.666 37.376, 126.666 37.376)>, 'length': 8.808165940498986, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100381898', 'geometry': <LINESTRING (126.666 37.376, 126.666 37.376)>, 'length': 8.808165940498986, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.666 37.376)>], 'access_zone': 0, 'weight': 0}
# 46
# {'link_id': '28200381869', 'geometry': <LINESTRING (126.666 37.376, 126.666 37.376)>, 'length': 11.30231739778934, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200381869', 'geometry': <LINESTRING (126.666 37.376, 126.666 37.376)>, 'length': 11.30231739778934, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.666 37.376)>], 'access_zone': 0, 'weight': 0}
# 47
# {'link_id': '28100068843', 'geometry': <LINESTRING (126.643 37.475, 126.644 37.476)>, 'length': 99.09156015333248, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100068843', 'geometry': <LINESTRING (126.643 37.475, 126.644 37.476)>, 'length': 99.09156015333248, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.644 37.476)>], 'access_zone': 0, 'weight': 0}
# 48
# {'link_id': '28100051568', 'geometry': <LINESTRING (126.644 37.476, 126.644 37.476)>, 'length': 6.616561172200675, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100051568', 'geometry': <LINESTRING (126.644 37.476, 126.644 37.476)>, 'length': 6.616561172200675, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.644 37.476)>], 'access_zone': 0, 'weight': 0}
# 49
# {'link_id': '28300179753', 'geometry': <LINESTRING (126.644 37.476, 126.644 37.476)>, 'length': 15.038909437923495, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300179753', 'geometry': <LINESTRING (126.644 37.476, 126.644 37.476)>, 'length': 15.038909437923495, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.644 37.476)>], 'access_zone': 0, 'weight': 0}
# 50
# {'link_id': '28100320044', 'geometry': <LINESTRING (126.664 37.387, 126.664 37.387)>, 'length': 27.24860793643287, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100320044', 'geometry': <LINESTRING (126.664 37.387, 126.664 37.387)>, 'length': 27.24860793643287, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.664 37.387)>], 'access_zone': 0, 'weight': 0}
# 51
# {'link_id': '28300168492', 'geometry': <LINESTRING (126.656 37.386, 126.656 37.386)>, 'length': 4.989747780211257, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300168492', 'geometry': <LINESTRING (126.656 37.386, 126.656 37.386)>, 'length': 4.989747780211257, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.656 37.386)>], 'access_zone': 0, 'weight': 0}
# 52
# {'link_id': '28100320079', 'geometry': <LINESTRING (126.677 37.384, 126.677 37.384, 126.677 37.384)>, 'length': 23.41704305365144, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100320079', 'geometry': <LINESTRING (126.677 37.384, 126.677 37.384, 126.677 37.384)>, 'length': 23.41704305365144, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.677 37.384)>], 'access_zone': 0, 'weight': 0}
# 53
# {'link_id': '28300168618', 'geometry': <LINESTRING (126.654 37.383, 126.654 37.383)>, 'length': 6.386875800763463, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300168618', 'geometry': <LINESTRING (126.654 37.383, 126.654 37.383)>, 'length': 6.386875800763463, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.654 37.383)>], 'access_zone': 0, 'weight': 0}
# 54
# {'link_id': '28100025953', 'geometry': <LINESTRING (126.654 37.383, 126.654 37.383, 126.654 37.383)>, 'length': 11.012521514079197, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100025953', 'geometry': <LINESTRING (126.654 37.383, 126.654 37.383, 126.654 37.383)>, 'length': 11.012521514079197, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.654 37.383)>], 'access_zone': 0, 'weight': 0}
# 55
# {'link_id': '28100005151', 'geometry': <LINESTRING (126.653 37.383, 126.653 37.383, 126.653 37.383, 126.653 37.383,...>, 'length': 72.18119502982096, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100005151', 'geometry': <LINESTRING (126.653 37.383, 126.653 37.383, 126.653 37.383, 126.653 37.383,...>, 'length': 72.18119502982096, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.654 37.383)>], 'access_zone': 0, 'weight': 0}
# 56
# {'link_id': '28100313511', 'geometry': <LINESTRING (126.662 37.382, 126.662 37.382)>, 'length': 5.320874114150096, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100313511', 'geometry': <LINESTRING (126.662 37.382, 126.662 37.382)>, 'length': 5.320874114150096, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.662 37.382)>], 'access_zone': 0, 'weight': 0}
# 57
# {'link_id': '28200255308', 'geometry': <LINESTRING (126.653 37.561, 126.653 37.561)>, 'length': 15.397770049490491, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200255308', 'geometry': <LINESTRING (126.653 37.561, 126.653 37.561)>, 'length': 15.397770049490491, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.653 37.561)>], 'access_zone': 0, 'weight': 0}
# 58
# {'link_id': '28200255326', 'geometry': <LINESTRING (126.652 37.561, 126.652 37.561, 126.652 37.561)>, 'length': 15.280524436815135, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200255326', 'geometry': <LINESTRING (126.652 37.561, 126.652 37.561, 126.652 37.561)>, 'length': 15.280524436815135, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.652 37.561)>], 'access_zone': 0, 'weight': 0}
# 59
# {'link_id': '28200255336', 'geometry': <LINESTRING (126.652 37.561, 126.652 37.56)>, 'length': 11.413245355234942, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200255336', 'geometry': <LINESTRING (126.652 37.561, 126.652 37.56)>, 'length': 11.413245355234942, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.652 37.561)>], 'access_zone': 0, 'weight': 0}
# 60
# {'link_id': '28200255290', 'geometry': <LINESTRING (126.653 37.561, 126.653 37.56)>, 'length': 27.150082187317025, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200255290', 'geometry': <LINESTRING (126.653 37.561, 126.653 37.56)>, 'length': 27.150082187317025, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.653 37.561)>], 'access_zone': 0, 'weight': 0}
# 61
# {'link_id': '28200255283', 'geometry': <LINESTRING (126.653 37.561, 126.653 37.561)>, 'length': 17.123922861322473, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200255283', 'geometry': <LINESTRING (126.653 37.561, 126.653 37.561)>, 'length': 17.123922861322473, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.653 37.561)>], 'access_zone': 0, 'weight': 0}
# 62
# {'link_id': '28200255338', 'geometry': <LINESTRING (126.653 37.561, 126.653 37.561, 126.653 37.561, 126.653 37.561)>, 'length': 26.665194151818508, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200255338', 'geometry': <LINESTRING (126.653 37.561, 126.653 37.561, 126.653 37.561, 126.653 37.561)>, 'length': 26.665194151818508, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.653 37.561)>], 'access_zone': 0, 'weight': 0}
# 63
# {'link_id': '28200255338', 'geometry': <LINESTRING (126.653 37.561, 126.653 37.561, 126.653 37.561, 126.653 37.561)>, 'length': 26.665194151818508, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.653 37.561)>], 'access_zone': 0, 'weight': 0}
# {'link_id': '28200255338', 'geometry': <LINESTRING (126.653 37.561, 126.653 37.561, 126.653 37.561, 126.653 37.561)>, 'length': 26.665194151818508, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.653 37.561)>, <POINT (126.653 37.561)>], 'access_zone': 0, 'weight': 0}
# 64
# {'link_id': '28200255343', 'geometry': <LINESTRING (126.653 37.561, 126.653 37.561, 126.653 37.561)>, 'length': 10.931101343067489, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200255343', 'geometry': <LINESTRING (126.653 37.561, 126.653 37.561, 126.653 37.561)>, 'length': 10.931101343067489, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.653 37.561)>], 'access_zone': 0, 'weight': 0}
# 65
# {'link_id': '28200255309', 'geometry': <LINESTRING (126.653 37.561, 126.652 37.561)>, 'length': 16.917945583544746, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200255309', 'geometry': <LINESTRING (126.653 37.561, 126.652 37.561)>, 'length': 16.917945583544746, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.653 37.561)>], 'access_zone': 0, 'weight': 0}
# 66
# {'link_id': '28100054553', 'geometry': <LINESTRING (126.676 37.57, 126.676 37.57, 126.675 37.57, 126.675 37.57, 126...>, 'length': 1089.6266141112685, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100054553', 'geometry': <LINESTRING (126.676 37.57, 126.676 37.57, 126.675 37.57, 126.675 37.57, 126...>, 'length': 1089.6266141112685, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.666 37.57)>], 'access_zone': 0, 'weight': 0}
# 67
# {'link_id': '28200284122', 'geometry': <LINESTRING (126.493 37.603, 126.493 37.603, 126.493 37.603, 126.493 37.603,...>, 'length': 82.08950747290115, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200284122', 'geometry': <LINESTRING (126.493 37.603, 126.493 37.603, 126.493 37.603, 126.493 37.603,...>, 'length': 82.08950747290115, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.493 37.603)>], 'access_zone': 0, 'weight': 0}
# 68
# {'link_id': '28100065645', 'geometry': <LINESTRING (126.669 37.544, 126.669 37.545, 126.669 37.545, 126.669 37.545)>, 'length': 84.92527809387683, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100065645', 'geometry': <LINESTRING (126.669 37.544, 126.669 37.545, 126.669 37.545, 126.669 37.545)>, 'length': 84.92527809387683, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.669 37.544)>], 'access_zone': 0, 'weight': 0}
# 69
# {'link_id': '28200406139', 'geometry': <LINESTRING (126.669 37.544, 126.669 37.544)>, 'length': 32.605285673469865, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200406139', 'geometry': <LINESTRING (126.669 37.544, 126.669 37.544)>, 'length': 32.605285673469865, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.669 37.544)>], 'access_zone': 0, 'weight': 0}
# 70
# {'link_id': '28100318517', 'geometry': <LINESTRING (126.669 37.544, 126.669 37.544, 126.669 37.544, 126.669 37.544,...>, 'length': 12.929051677516247, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100318517', 'geometry': <LINESTRING (126.669 37.544, 126.669 37.544, 126.669 37.544, 126.669 37.544,...>, 'length': 12.929051677516247, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.669 37.544)>], 'access_zone': 0, 'weight': 0}
# 71
# {'link_id': '28200000275', 'geometry': <LINESTRING (126.669 37.544, 126.669 37.544)>, 'length': 31.217228479593775, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200000275', 'geometry': <LINESTRING (126.669 37.544, 126.669 37.544)>, 'length': 31.217228479593775, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.669 37.544)>], 'access_zone': 0, 'weight': 0}
# 72
# {'link_id': '28100279982', 'geometry': <LINESTRING (126.668 37.545, 126.668 37.545, 126.668 37.545, 126.668 37.545,...>, 'length': 143.67808530308926, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100279982', 'geometry': <LINESTRING (126.668 37.545, 126.668 37.545, 126.668 37.545, 126.668 37.545,...>, 'length': 143.67808530308926, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.669 37.544)>], 'access_zone': 0, 'weight': 0}
# 73
# {'link_id': '28100279982', 'geometry': <LINESTRING (126.668 37.545, 126.668 37.545, 126.668 37.545, 126.668 37.545,...>, 'length': 143.67808530308926, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.669 37.544)>], 'access_zone': 0, 'weight': 0}
# {'link_id': '28100279982', 'geometry': <LINESTRING (126.668 37.545, 126.668 37.545, 126.668 37.545, 126.668 37.545,...>, 'length': 143.67808530308926, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.669 37.544)>, <POINT (126.668 37.544)>], 'access_zone': 0, 'weight': 0}
# 74
# {'link_id': '28100279967', 'geometry': <LINESTRING (126.668 37.544, 126.668 37.544, 126.668 37.544, 126.668 37.544,...>, 'length': 96.22470625184252, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100279967', 'geometry': <LINESTRING (126.668 37.544, 126.668 37.544, 126.668 37.544, 126.668 37.544,...>, 'length': 96.22470625184252, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.668 37.544)>], 'access_zone': 0, 'weight': 0}
# 75
# {'link_id': '28100133897', 'geometry': <LINESTRING (126.677 37.551, 126.677 37.551)>, 'length': 5.772246106381179, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100133897', 'geometry': <LINESTRING (126.677 37.551, 126.677 37.551)>, 'length': 5.772246106381179, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.677 37.551)>], 'access_zone': 0, 'weight': 0}
# 76
# {'link_id': '28100279976', 'geometry': <LINESTRING (126.668 37.547, 126.668 37.547, 126.668 37.547, 126.668 37.547,...>, 'length': 73.18236264142476, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100279976', 'geometry': <LINESTRING (126.668 37.547, 126.668 37.547, 126.668 37.547, 126.668 37.547,...>, 'length': 73.18236264142476, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.668 37.547)>], 'access_zone': 0, 'weight': 0}
# 77
# {'link_id': '28300280027', 'geometry': <LINESTRING (126.668 37.547, 126.668 37.547, 126.668 37.547, 126.668 37.547,...>, 'length': 16.70603848472793, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300280027', 'geometry': <LINESTRING (126.668 37.547, 126.668 37.547, 126.668 37.547, 126.668 37.547,...>, 'length': 16.70603848472793, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.668 37.547)>], 'access_zone': 0, 'weight': 0}
# 78
# {'link_id': '28100280235', 'geometry': <LINESTRING (126.668 37.547, 126.668 37.547, 126.668 37.547, 126.668 37.547,...>, 'length': 8.590741211850077, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100280235', 'geometry': <LINESTRING (126.668 37.547, 126.668 37.547, 126.668 37.547, 126.668 37.547,...>, 'length': 8.590741211850077, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.668 37.547)>], 'access_zone': 0, 'weight': 0}
# 79
# {'link_id': '28100280233', 'geometry': <LINESTRING (126.668 37.547, 126.668 37.547, 126.668 37.547)>, 'length': 4.273351279352689, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100280233', 'geometry': <LINESTRING (126.668 37.547, 126.668 37.547, 126.668 37.547)>, 'length': 4.273351279352689, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.668 37.547)>], 'access_zone': 0, 'weight': 0}
# 80
# {'link_id': '28100279976', 'geometry': <LINESTRING (126.668 37.547, 126.668 37.547, 126.668 37.547, 126.668 37.547,...>, 'length': 73.18236264142476, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.668 37.547)>], 'access_zone': 0, 'weight': 0}
# {'link_id': '28100279976', 'geometry': <LINESTRING (126.668 37.547, 126.668 37.547, 126.668 37.547, 126.668 37.547,...>, 'length': 73.18236264142476, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.668 37.547)>, <POINT (126.668 37.547)>], 'access_zone': 0, 'weight': 0}
# 81
# {'link_id': '28100101466', 'geometry': <LINESTRING (126.754 37.449, 126.755 37.449, 126.755 37.449)>, 'length': 34.417449134731314, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100101466', 'geometry': <LINESTRING (126.754 37.449, 126.755 37.449, 126.755 37.449)>, 'length': 34.417449134731314, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.755 37.449)>], 'access_zone': 0, 'weight': 0}
# 82
# {'link_id': '28100073621', 'geometry': <LINESTRING (126.754 37.449, 126.754 37.449, 126.754 37.449, 126.754 37.449)>, 'length': 52.73405374851259, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100073621', 'geometry': <LINESTRING (126.754 37.449, 126.754 37.449, 126.754 37.449, 126.754 37.449)>, 'length': 52.73405374851259, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.754 37.449)>], 'access_zone': 0, 'weight': 0}
# 83
# {'link_id': '28100073621', 'geometry': <LINESTRING (126.754 37.449, 126.754 37.449, 126.754 37.449, 126.754 37.449)>, 'length': 52.73405374851259, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.754 37.449)>], 'access_zone': 0, 'weight': 0}
# {'link_id': '28100073621', 'geometry': <LINESTRING (126.754 37.449, 126.754 37.449, 126.754 37.449, 126.754 37.449)>, 'length': 52.73405374851259, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.754 37.449)>, <POINT (126.754 37.449)>], 'access_zone': 0, 'weight': 0}
# 84
# {'link_id': '28100350289', 'geometry': <LINESTRING (126.735 37.435, 126.735 37.435, 126.735 37.435, 126.735 37.435,...>, 'length': 67.89893804878986, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100350289', 'geometry': <LINESTRING (126.735 37.435, 126.735 37.435, 126.735 37.435, 126.735 37.435,...>, 'length': 67.89893804878986, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.734 37.435)>], 'access_zone': 0, 'weight': 0}
# 85
# {'link_id': '28100304595', 'geometry': <LINESTRING (126.743 37.511, 126.743 37.511, 126.743 37.51, 126.743 37.51, 1...>, 'length': 23.46792144465154, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100304595', 'geometry': <LINESTRING (126.743 37.511, 126.743 37.511, 126.743 37.51, 126.743 37.51, 1...>, 'length': 23.46792144465154, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.743 37.51)>], 'access_zone': 0, 'weight': 0}
# 86
# {'link_id': '28200304812', 'geometry': <LINESTRING (126.742 37.51, 126.742 37.51)>, 'length': 13.608072331817883, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200304812', 'geometry': <LINESTRING (126.742 37.51, 126.742 37.51)>, 'length': 13.608072331817883, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.742 37.51)>], 'access_zone': 0, 'weight': 0}
# 87
# {'link_id': '28200304640', 'geometry': <LINESTRING (126.742 37.51, 126.742 37.51)>, 'length': 9.34166024819453, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200304640', 'geometry': <LINESTRING (126.742 37.51, 126.742 37.51)>, 'length': 9.34166024819453, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.742 37.51)>], 'access_zone': 0, 'weight': 0}
# 88
# {'link_id': '28200404119', 'geometry': <LINESTRING (126.743 37.511, 126.743 37.511, 126.743 37.511)>, 'length': 24.812871340922612, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200404119', 'geometry': <LINESTRING (126.743 37.511, 126.743 37.511, 126.743 37.511)>, 'length': 24.812871340922612, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.743 37.511)>], 'access_zone': 0, 'weight': 0}
# 89
# {'link_id': '28200304812', 'geometry': <LINESTRING (126.742 37.51, 126.742 37.51)>, 'length': 13.608072331817883, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.742 37.51)>], 'access_zone': 0, 'weight': 0}
# {'link_id': '28200304812', 'geometry': <LINESTRING (126.742 37.51, 126.742 37.51)>, 'length': 13.608072331817883, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.742 37.51)>, <POINT (126.742 37.51)>], 'access_zone': 0, 'weight': 0}
# 90
# {'link_id': '28100304594', 'geometry': <LINESTRING (126.742 37.51, 126.743 37.51)>, 'length': 29.98332371035289, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100304594', 'geometry': <LINESTRING (126.742 37.51, 126.743 37.51)>, 'length': 29.98332371035289, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.742 37.51)>], 'access_zone': 0, 'weight': 0}
# 91
# {'link_id': '28200350269', 'geometry': <LINESTRING (126.735 37.437, 126.735 37.437, 126.734 37.437, 126.734 37.437)>, 'length': 47.272545180571306, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200350269', 'geometry': <LINESTRING (126.735 37.437, 126.735 37.437, 126.734 37.437, 126.734 37.437)>, 'length': 47.272545180571306, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.734 37.437)>], 'access_zone': 0, 'weight': 0}
# 92
# ...
# 4425
# {'link_id': '28300201876', 'geometry': <LINESTRING (126.722 37.452, 126.722 37.452)>, 'length': 3.1816159991843618, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300201876', 'geometry': <LINESTRING (126.722 37.452, 126.722 37.452)>, 'length': 3.1816159991843618, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.722 37.452)>], 'access_zone': 0, 'weight': 0}
# 4426
# {'link_id': '28300201779', 'geometry': <LINESTRING (126.721 37.452, 126.721 37.452, 126.722 37.452, 126.722 37.452,...>, 'length': 95.1311810558515, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300201779', 'geometry': <LINESTRING (126.721 37.452, 126.721 37.452, 126.722 37.452, 126.722 37.452,...>, 'length': 95.1311810558515, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.722 37.452)>], 'access_zone': 0, 'weight': 0}
# 4427
# {'link_id': '28300410506', 'geometry': <LINESTRING (126.603 37.59, 126.603 37.59, 126.604 37.59, 126.604 37.59)>, 'length': 25.261783410511473, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300410506', 'geometry': <LINESTRING (126.603 37.59, 126.603 37.59, 126.604 37.59, 126.604 37.59)>, 'length': 25.261783410511473, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.603 37.59)>], 'access_zone': 0, 'weight': 0}
# 4428
# {'link_id': '28300410385', 'geometry': <LINESTRING (126.602 37.591, 126.602 37.591, 126.602 37.591, 126.602 37.591)>, 'length': 22.66337965596187, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300410385', 'geometry': <LINESTRING (126.602 37.591, 126.602 37.591, 126.602 37.591, 126.602 37.591)>, 'length': 22.66337965596187, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.602 37.591)>], 'access_zone': 0, 'weight': 0}
# 4429
# {'link_id': '28300139939', 'geometry': <LINESTRING (126.602 37.591, 126.602 37.591)>, 'length': 3.105178211666959, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300139939', 'geometry': <LINESTRING (126.602 37.591, 126.602 37.591)>, 'length': 3.105178211666959, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.602 37.591)>], 'access_zone': 0, 'weight': 0}
# 4430
# {'link_id': '28300136736', 'geometry': <LINESTRING (126.651 37.36, 126.651 37.36, 126.652 37.36)>, 'length': 67.85046745705058, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300136736', 'geometry': <LINESTRING (126.651 37.36, 126.651 37.36, 126.652 37.36)>, 'length': 67.85046745705058, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.652 37.36)>], 'access_zone': 0, 'weight': 0}
# 4431
# {'link_id': '28300410916', 'geometry': <LINESTRING (126.602 37.591, 126.602 37.591)>, 'length': 1.6167586588059315, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300410916', 'geometry': <LINESTRING (126.602 37.591, 126.602 37.591)>, 'length': 1.6167586588059315, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.602 37.591)>], 'access_zone': 0, 'weight': 0}
# 4432
# {'link_id': '28300410380', 'geometry': <LINESTRING (126.602 37.591, 126.602 37.591)>, 'length': 2.334354527419778, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300410380', 'geometry': <LINESTRING (126.602 37.591, 126.602 37.591)>, 'length': 2.334354527419778, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.602 37.591)>], 'access_zone': 0, 'weight': 0}
# 4433
# {'link_id': '28300136745', 'geometry': <LINESTRING (126.651 37.36, 126.651 37.36, 126.652 37.361)>, 'length': 69.71608896612285, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300136745', 'geometry': <LINESTRING (126.651 37.36, 126.651 37.36, 126.652 37.361)>, 'length': 69.71608896612285, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.652 37.361)>], 'access_zone': 0, 'weight': 0}
# 4434
# {'link_id': '28300136746', 'geometry': <LINESTRING (126.652 37.361, 126.652 37.361)>, 'length': 7.057943512008769, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300136746', 'geometry': <LINESTRING (126.652 37.361, 126.652 37.361)>, 'length': 7.057943512008769, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.652 37.361)>], 'access_zone': 0, 'weight': 0}
# 4435
# {'link_id': '28300411063', 'geometry': <LINESTRING (126.602 37.591, 126.602 37.591)>, 'length': 13.823545308588018, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300411063', 'geometry': <LINESTRING (126.602 37.591, 126.602 37.591)>, 'length': 13.823545308588018, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.602 37.591)>], 'access_zone': 0, 'weight': 0}
# 4436
# {'link_id': '28300411068', 'geometry': <LINESTRING (126.602 37.591, 126.602 37.591, 126.602 37.591, 126.602 37.591)>, 'length': 21.62832616926001, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300411068', 'geometry': <LINESTRING (126.602 37.591, 126.602 37.591, 126.602 37.591, 126.602 37.591)>, 'length': 21.62832616926001, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.602 37.591)>], 'access_zone': 0, 'weight': 0}
# 4437
# {'link_id': '28300411092', 'geometry': <LINESTRING (126.603 37.592, 126.603 37.592)>, 'length': 1.3885008370671388, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300411092', 'geometry': <LINESTRING (126.603 37.592, 126.603 37.592)>, 'length': 1.3885008370671388, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.603 37.592)>], 'access_zone': 0, 'weight': 0}
# 4438
# {'link_id': '28300410897', 'geometry': <LINESTRING (126.603 37.592, 126.603 37.592)>, 'length': 2.186100164970275, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300410897', 'geometry': <LINESTRING (126.603 37.592, 126.603 37.592)>, 'length': 2.186100164970275, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.603 37.592)>], 'access_zone': 0, 'weight': 0}
# 4439
# {'link_id': '28300136730', 'geometry': <LINESTRING (126.652 37.359, 126.652 37.359, 126.653 37.36)>, 'length': 85.76367436910117, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300136730', 'geometry': <LINESTRING (126.652 37.359, 126.652 37.359, 126.653 37.36)>, 'length': 85.76367436910117, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.653 37.36)>], 'access_zone': 0, 'weight': 0}
# 4440
# {'link_id': '28300411075', 'geometry': <LINESTRING (126.603 37.592, 126.603 37.592)>, 'length': 16.046112237915416, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300411075', 'geometry': <LINESTRING (126.603 37.592, 126.603 37.592)>, 'length': 16.046112237915416, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.603 37.592)>], 'access_zone': 0, 'weight': 0}
# 4441
# {'link_id': '28300139644', 'geometry': <LINESTRING (126.604 37.592, 126.604 37.592)>, 'length': 3.796093156235157, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300139644', 'geometry': <LINESTRING (126.604 37.592, 126.604 37.592)>, 'length': 3.796093156235157, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.604 37.592)>], 'access_zone': 0, 'weight': 0}
# 4442
# {'link_id': '28300411096', 'geometry': <LINESTRING (126.603 37.592, 126.603 37.592, 126.603 37.592, 126.603 37.592,...>, 'length': 25.498240221217902, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300411096', 'geometry': <LINESTRING (126.603 37.592, 126.603 37.592, 126.603 37.592, 126.603 37.592,...>, 'length': 25.498240221217902, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.603 37.592)>], 'access_zone': 0, 'weight': 0}
# 4443
# {'link_id': '28300139643', 'geometry': <LINESTRING (126.604 37.592, 126.604 37.592)>, 'length': 2.368045020095165, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300139643', 'geometry': <LINESTRING (126.604 37.592, 126.604 37.592)>, 'length': 2.368045020095165, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.604 37.592)>], 'access_zone': 0, 'weight': 0}
# 4444
# {'link_id': '28300135578', 'geometry': <LINESTRING (126.69 37.448, 126.69 37.448)>, 'length': 3.429279679740036, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300135578', 'geometry': <LINESTRING (126.69 37.448, 126.69 37.448)>, 'length': 3.429279679740036, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.69 37.448)>], 'access_zone': 0, 'weight': 0}
# 4445
# {'link_id': '28300177327', 'geometry': <LINESTRING (126.748 37.426, 126.748 37.426)>, 'length': 7.361529720493109, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300177327', 'geometry': <LINESTRING (126.748 37.426, 126.748 37.426)>, 'length': 7.361529720493109, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.748 37.426)>], 'access_zone': 0, 'weight': 0}
# 4446
# {'link_id': '28200099858', 'geometry': <LINESTRING (126.75 37.423, 126.749 37.423)>, 'length': 47.16240460900267, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200099858', 'geometry': <LINESTRING (126.75 37.423, 126.749 37.423)>, 'length': 47.16240460900267, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.75 37.423)>], 'access_zone': 0, 'weight': 0}
# 4447
# {'link_id': '28200224932', 'geometry': <LINESTRING (126.749 37.42, 126.749 37.42, 126.749 37.42)>, 'length': 18.976481335297194, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28200224932', 'geometry': <LINESTRING (126.749 37.42, 126.749 37.42, 126.749 37.42)>, 'length': 18.976481335297194, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.749 37.42)>], 'access_zone': 0, 'weight': 0}
# 4448
# {'link_id': '28100048253', 'geometry': <LINESTRING (126.747 37.422, 126.747 37.422, 126.747 37.422, 126.747 37.422,...>, 'length': 229.68766518735558, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28100048253', 'geometry': <LINESTRING (126.747 37.422, 126.747 37.422, 126.747 37.422, 126.747 37.422,...>, 'length': 229.68766518735558, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.747 37.422)>], 'access_zone': 0, 'weight': 0}
# 4449
# {'link_id': '28300180451', 'geometry': <LINESTRING (126.743 37.43, 126.743 37.43)>, 'length': 10.861188871445302, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300180451', 'geometry': <LINESTRING (126.743 37.43, 126.743 37.43)>, 'length': 10.861188871445302, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.743 37.43)>], 'access_zone': 0, 'weight': 0}
# 4450
# {'link_id': '28300183811', 'geometry': <LINESTRING (126.741 37.43, 126.741 37.43)>, 'length': 11.61625549490839, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300183811', 'geometry': <LINESTRING (126.741 37.43, 126.741 37.43)>, 'length': 11.61625549490839, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.741 37.43)>], 'access_zone': 0, 'weight': 0}
# 4451
# {'link_id': '28300411078', 'geometry': <LINESTRING (126.603 37.592, 126.603 37.592)>, 'length': 1.9571648902453636, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300411078', 'geometry': <LINESTRING (126.603 37.592, 126.603 37.592)>, 'length': 1.9571648902453636, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.603 37.592)>], 'access_zone': 0, 'weight': 0}
# 4452
# {'link_id': '28300201425', 'geometry': <LINESTRING (126.719 37.451, 126.719 37.451, 126.719 37.451, 126.719 37.451,...>, 'length': 152.5706574258688, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300201425', 'geometry': <LINESTRING (126.719 37.451, 126.719 37.451, 126.719 37.451, 126.719 37.451,...>, 'length': 152.5706574258688, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.719 37.452)>], 'access_zone': 0, 'weight': 0}
# 4453
# {'link_id': '28300201820', 'geometry': <LINESTRING (126.719 37.452, 126.719 37.452)>, 'length': 4.405418308086679, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300201820', 'geometry': <LINESTRING (126.719 37.452, 126.719 37.452)>, 'length': 4.405418308086679, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.719 37.452)>], 'access_zone': 0, 'weight': 0}
# 4454
# {'link_id': '28300201819', 'geometry': <LINESTRING (126.719 37.452, 126.719 37.452)>, 'length': 4.935304315491731, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300201819', 'geometry': <LINESTRING (126.719 37.452, 126.719 37.452)>, 'length': 4.935304315491731, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.719 37.452)>], 'access_zone': 0, 'weight': 0}
# 4455
# {'link_id': '28300200870', 'geometry': <LINESTRING (126.699 37.447, 126.699 37.447)>, 'length': 23.701334792273357, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': 0, 'access_zone': 0, 'weight': 0}
# {'link_id': '28300200870', 'geometry': <LINESTRING (126.699 37.447, 126.699 37.447)>, 'length': 23.701334792273357, 'slope': 0, 'stair_steep': 0, 'sidewalk_curb': 0, 'crosswalk_curb': 0, 'bollard': [<POINT (126.699 37.447)>], 'access_zone': 0, 'weight': 0}

# %%
# 저장할 파일 경로 지정
file_path_to_save = 'C:/my_code/moduroad/moduroad_app/cashe_data/api_graph_bollard.pickle'

# api_graph 객체를 피클 파일로 저장
with open(file_path_to_save, 'wb') as file:
    pickle.dump(G, file)
